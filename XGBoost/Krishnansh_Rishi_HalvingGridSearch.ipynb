# %%
import numpy as np
import pandas as pd
import os
import xgboost as xgb
from sklearn.metrics import confusion_matrix, roc_auc_score, accuracy_score, f1_score, roc_curve
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, GridSearchCV, HalvingGridSearchCV
import matplotlib as mpl
import matplotlib.pyplot as plt
from copy import deepcopy
import time
from sklearn.multioutput import MultiOutputClassifier

mpl.rcParams['figure.dpi'] = 200

# %% [markdown]
# ## HYPERBAND SEARCH IMPLEMENTATION

# %%
import copy

import numpy as np
from scipy.stats import rankdata

from sklearn.utils import check_random_state
from sklearn.model_selection._search import BaseSearchCV, ParameterSampler


__all__ = ['HyperbandSearchCV']


class HyperbandSearchCV(GridSearchCV):
    def __init__(self, estimator, param_distributions,
                 resource_param='n_estimators', eta=3, min_iter=1,
                 max_iter=81, skip_last=0, scoring=None, n_jobs=1,
                 refit=True, cv=None,
                 verbose=0, pre_dispatch='2*n_jobs', random_state=None,
                 error_score='raise', return_train_score=False):
        self.param_distributions = param_distributions
        self.resource_param = resource_param
        self.eta = eta
        self.min_iter = min_iter
        self.max_iter = max_iter
        self.skip_last = skip_last
        self.random_state = random_state

        super(HyperbandSearchCV, self).__init__(
            estimator=estimator,param_grid=param_distributions, scoring=scoring, n_jobs=n_jobs,
            refit=refit, cv=cv, verbose=verbose,
            pre_dispatch=pre_dispatch, error_score=error_score,
            return_train_score=return_train_score)

    def _run_search(self, evaluate_candidates):
        self._validate_input()

        s_max = int(np.floor(np.log(self.max_iter / self.min_iter) / np.log(self.eta)))
        B = (s_max + 1) * self.max_iter

        refit_metric = 'score'
        random_state = check_random_state(self.random_state)

        if self.skip_last > s_max:
            raise ValueError('skip_last is higher than the total number of rounds')

        for round_index, s in enumerate(reversed(range(s_max + 1))):
            n = int(np.ceil(int(B / self.max_iter / (s + 1)) * np.power(self.eta, s)))

            # initial number of iterations per config
            r = self.max_iter / np.power(self.eta, s)
            configurations = list(ParameterSampler(param_distributions=self.param_distributions,
                                                   n_iter=n,
                                                   random_state=random_state))

            if self.verbose > 0:
                print('Starting bracket {0} (out of {1}) of hyperband'
                      .format(round_index + 1, s_max + 1))

            for i in range((s + 1) - self.skip_last):

                n_configs = np.floor(n / np.power(self.eta, i))  # n_i
                n_iterations = int(r * np.power(self.eta, i))  # r_i
                n_to_keep = int(np.floor(n_configs / self.eta))

                if self.verbose > 0:
                    msg = ('Starting successive halving iteration {0} out of'
                           ' {1}. Fitting {2} configurations, with'
                           ' resource_param {3} set to {4}')

                    if n_to_keep > 0:
                        msg += ', and keeping the best {5} configurations.'

                    msg = msg.format(i + 1, s + 1, len(configurations),
                                     self.resource_param, n_iterations,
                                     n_to_keep)
                    print(msg)

                # Set the cost parameter for every configuration
                parameters = copy.deepcopy(configurations)
                for configuration in parameters:
                    configuration[self.resource_param] = n_iterations

                results = evaluate_candidates(parameters)

                if n_to_keep > 0:
                    top_configurations = [x for _, x in sorted(zip(results['rank_test_%s' % refit_metric],
                                                                   results['params']),
                                                               key=lambda x: x[0])]

                    configurations = top_configurations[:n_to_keep]

            if self.skip_last > 0:
                print('Skipping the last {0} successive halving iterations'
                      .format(self.skip_last))

    def fit(self, X, y=None, groups=None, **fit_params):
        """Run fit with all sets of parameters.

        Parameters
        ----------
        X : array-like, shape = [n_samples, n_features]
            Training vector, where n_samples is the number of samples and
            n_features is the number of features.

        y : array-like, shape = [n_samples] or [n_samples, n_output], optional
            Target relative to X for classification or regression;
            None for unsupervised learning.

        groups : array-like, with shape (n_samples,), optional
            Group labels for the samples used while splitting the dataset into
            train/test set.
t
        **fit_params : dict of string -> object
            Parameters passed to the ``fit`` method of the estimator
        """
        super().fit(X=X, y=y, groups=groups, **fit_params)

        s_max = int(np.floor(np.log(self.max_iter / self.min_iter) / np.log(self.eta)))
        B = (s_max + 1) * self.max_iter

        brackets = []
        for round_index, s in enumerate(reversed(range(s_max + 1))):
            n = int(np.ceil(int(B / self.max_iter / (s + 1)) * np.power(self.eta, s)))
            n_configs = int(sum([np.floor(n / np.power(self.eta, i))
                                 for i in range((s + 1) - self.skip_last)]))
            bracket = (round_index + 1) * np.ones(n_configs)
            brackets.append(bracket)

        self.cv_results_['hyperband_bracket'] = np.hstack(brackets)

        return self

    def _validate_input(self):
        if not isinstance(self.min_iter, int) or self.min_iter <= 0:
            raise ValueError('min_iter should be a positive integer, got %s' %
                             self.min_iter)

        if not isinstance(self.max_iter, int) or self.max_iter <= 0:
            raise ValueError('max_iter should be a positive integer, got %s' %
                             self.max_iter)

        if self.max_iter < self.min_iter:
            raise ValueError('max_iter should be bigger than min_iter, got'
                             'max_iter=%d and min_iter=%d' % (self.max_iter,
                                                              self.min_iter))

        if not isinstance(self.skip_last, int) or self.skip_last < 0:
            raise ValueError('skip_last should be an integer, got %s' %
                             self.skip_last)

        if not isinstance(self.eta, int) or not self.eta > 1:
            raise ValueError('eta should be a positive integer, got %s' %
                             self.eta)

        if self.resource_param not in self.estimator.get_params().keys():
            raise ValueError('resource_param is set to %s, but base_estimator %s '
                             'does not have a parameter with that name' %
                             (self.resource_param,
                              self.estimator.__class__.__name__))

# %%
Y = np.load("/kaggle/input/xgbdata/Y_1499.npy")

# %%
Y.shape[0]
# Out:
# 142246

# %%
IX = np.arange(Y.shape[0])
IX_train, IX_test, _,_ = train_test_split( IX, IX, train_size=0.2, random_state=42)

# %%
y_train, y_test = Y[IX_train[:10000],:], Y[IX_test[:10000],:]

# %%
X_train = np.asarray(pd.read_csv('/kaggle/input/cafa-encoder-200/train_encoded.csv'))[:10000]
X_test = np.asarray(pd.read_csv('/kaggle/input/cafa-encoder-200/test_encoded.csv'))[:10000]

# %%
labels_to_consider = np.load("/kaggle/input/xgbdata/Y_1499_labels.npy")

# %%
clf_xgb = xgb.XGBClassifier(objective="binary:logistic", random_state=42, tree_method = "gpu_hist")

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (10000, 1499)
# (10000, 200)

# %%
param_grid = {'gamma': [0,6.4,25.6,102.4],
              'learning_rate': [0.03, 0.3, 1],
              'max_depth': [3,6,12],
              'reg_alpha': [0,6.4,25.6],
              'reg_lambda': [0.5,6.4,25.6]}

search0 = HyperbandSearchCV(estimator=clf_xgb,
                            param_distributions = param_grid,
                            resource_param='n_estimators',
                            scoring='roc_auc',
                           return_train_score=True,
                           verbose=2,
                           cv=3)
search0.fit(X_train,y_train)
# print(search0.best_params_)
# Out:
# Starting bracket 1 (out of 5) of hyperband
# Starting successive halving iteration 1 out of 5. Fitting 81 configurations, with resource_param n_estimators set to 1, and keeping the best 27 configurations.
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.0s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   5.4s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.8s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.7s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.3s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   3.9s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=0, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=0, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=0, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.6s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.5s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   5.1s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.4s
# [CV] END gamma=25.6, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   5.0s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   5.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   5.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   5.2s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.0s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.3s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.5s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   5.0s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.5s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.4s
# [CV] END gamma=0, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.4s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.4s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.9s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.8s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.8s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   5.0s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.9s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   5.0s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   7.2s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   6.6s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   6.6s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.9s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.1s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.0s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.6s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.3s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.4s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.0s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.6s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.6s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.8s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.0s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.9s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   5.0s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.9s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=0, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   8.8s
# [CV] END gamma=0, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   8.9s
# [CV] END gamma=0, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   7.9s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   5.3s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   5.2s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   5.5s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   3.9s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.8s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.5s
# [CV] END gamma=0, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.5s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.5s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.0s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   8.8s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   8.7s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   7.8s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.0s
# [CV] END gamma=0, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=  11.0s
# [CV] END gamma=0, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=  11.6s
# [CV] END gamma=0, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=  10.8s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.8s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.5s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.7s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.3s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.3, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.3s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=0, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=6.4, reg_lambda=6.4; total time=   4.4s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.3s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=1, reg_alpha=0, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.9s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=3, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.5s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=1, reg_alpha=6.4, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=102.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.2s
# [CV] END gamma=102.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=25.6; total time=   4.7s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   9.4s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   9.3s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=0, reg_lambda=6.4; total time=   9.3s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.2s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=6.4; total time=   4.1s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.9s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   5.0s
# [CV] END gamma=0, learning_rate=1, max_depth=6, n_estimators=1, reg_alpha=6.4, reg_lambda=25.6; total time=   4.7s
# [CV] END gamma=6.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# [CV] END gamma=6.4, learning_rate=1, max_depth=12, n_estimators=1, reg_alpha=25.6, reg_lambda=0.5; total time=   4.2s
# Starting successive halving iteration 2 out of 5. Fitting 27 configurations, with resource_param n_estimators set to 3, and keeping the best 9 configurations.
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=  13.2s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=  13.2s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=  13.2s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=  33.0s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=  32.9s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=  32.7s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.7s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.7s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.8s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   6.5s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   6.5s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   6.3s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.7s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.5s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.7s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.0s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.7s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   9.2s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   9.5s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   9.0s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   6.3s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   6.4s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=   5.7s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=   5.9s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.6s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=6, n_estimators=3, reg_alpha=0, reg_lambda=25.6; total time=   6.4s
# [CV] END gamma=25.6, learning_rate=1, max_depth=6, n_estimators=3, reg_alpha=0, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=6, n_estimators=3, reg_alpha=0, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   6.0s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=25.6, reg_lambda=0.5; total time=   5.7s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=25.6, reg_lambda=0.5; total time=   5.9s
# [CV] END gamma=25.6, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=25.6, reg_lambda=0.5; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   6.2s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.7s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   6.3s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=0, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   6.1s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=6.4, reg_lambda=0.5; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=1, max_depth=3, n_estimators=3, reg_alpha=0, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.7s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   6.5s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.9s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=25.6; total time=   6.2s
# [CV] END gamma=102.4, learning_rate=0.3, max_depth=6, n_estimators=3, reg_alpha=6.4, reg_lambda=25.6; total time=   5.7s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.7s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.3, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=25.6; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=6.4; total time=   5.8s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=6.4; total time=   5.6s
# [CV] END gamma=25.6, learning_rate=0.03, max_depth=6, n_estimators=3, reg_alpha=25.6, reg_lambda=6.4; total time=   6.1s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.7s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.6s
# [CV] END gamma=102.4, learning_rate=0.03, max_depth=12, n_estimators=3, reg_alpha=6.4, reg_lambda=6.4; total time=   5.6s
# Starting successive halving iteration 3 out of 5. Fitting 9 configurations, with resource_param n_estimators set to 9, and keeping the best 3 configurations.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time= 1.9min
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time= 1.9min
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time= 1.9min
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=9, reg_alpha=6.4, reg_lambda=6.4; total time=  13.2s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=9, reg_alpha=6.4, reg_lambda=6.4; total time=  13.1s
# [CV] END gamma=6.4, learning_rate=1, max_depth=6, n_estimators=9, reg_alpha=6.4, reg_lambda=6.4; total time=  13.6s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=9, reg_alpha=6.4, reg_lambda=6.4; total time=  11.6s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=9, reg_alpha=6.4, reg_lambda=6.4; total time=  11.6s
# [CV] END gamma=6.4, learning_rate=1, max_depth=3, n_estimators=9, reg_alpha=6.4, reg_lambda=6.4; total time=  11.6s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=0.5; total time=  33.4s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=0.5; total time=  32.6s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=0.5; total time=  32.4s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time=  21.2s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time=  21.4s
# [CV] END gamma=6.4, learning_rate=0.3, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time=  20.0s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=0.5; total time=  33.3s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=0.5; total time=  32.6s
# [CV] END gamma=6.4, learning_rate=0.03, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=0.5; total time=  32.4s
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time= 1.9min
# [CV] END gamma=0, learning_rate=1, max_depth=12, n_estimators=9, reg_alpha=0, reg_lambda=6.4; total time= 1.9min

# %%
print(search0.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(search0.best_params_)
#
# NameError: name 'search0' is not defined
