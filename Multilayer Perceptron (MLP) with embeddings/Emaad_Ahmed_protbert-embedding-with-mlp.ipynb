# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import progressbar
import os
from sklearn.model_selection import train_test_split
import time
from sklearn.metrics import roc_auc_score
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ### Loading ProtBert Train embeddings and labels

# %%
train_embeddings = np.load('/kaggle/input/t5embeds/train_embeds.npy')
labels_y = np.load("/kaggle/input/xgbdata/Y_1499.npy")

# %% [markdown]
# ### Splitting Train Dataset into Train and Validation Dataset

# %%
X_trn, X_tst, y_trn, y_tst = train_test_split( train_embeddings, labels_y, test_size=0.2, random_state=42)

# %%
column_num = train_embeddings.shape[1]
train_df = pd.DataFrame(train_embeddings, columns = ["Column_" + str(i) for i in range(1, column_num+1)])
print(train_df.shape)
# Out:
# (142246, 1024)

# %%
train_terms = pd.read_csv("/kaggle/input/cafa-5-protein-function-prediction/Train/train_terms.tsv",sep="\t")
print(train_terms.shape)
# Out:
# (5363863, 3)

# %% [markdown]
# ### Defining and Training the model

# %%
INPUT_SHAPE = (1024, 1) 
BATCH_SIZE = 5120

model = tf.keras.Sequential([
    tf.keras.layers.Reshape(INPUT_SHAPE, input_shape=(1024,)),
    tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu'),
    tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Flatten(),   
    tf.keras.layers.Dense(units=712, activation='leaky_relu'),
    tf.keras.layers.Dense(units=1012, activation='leaky_relu'),
    tf.keras.layers.Dense(units=1499,activation='sigmoid')
])

checkpoint_path = "training/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)


cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1,save_freq='epoch')

# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['binary_accuracy', tf.keras.metrics.AUC()]
)

history = model.fit(
    X_trn, y_trn,
    batch_size=BATCH_SIZE,
    epochs=100,callbacks=[cp_callback]
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 0.1621 - binary_accuracy: 0.9441 - auc: 0.7065
# Epoch 1: saving model to training/cp.ckpt
# 23/23 [==============================] - 21s 418ms/step - loss: 0.1621 - binary_accuracy: 0.9441 - auc: 0.7065
# Epoch 2/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0766 - binary_accuracy: 0.9801 - auc: 0.8385
# Epoch 2: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 410ms/step - loss: 0.0766 - binary_accuracy: 0.9801 - auc: 0.8385
# Epoch 3/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0729 - binary_accuracy: 0.9804 - auc: 0.8652
# Epoch 3: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 403ms/step - loss: 0.0729 - binary_accuracy: 0.9804 - auc: 0.8652
# Epoch 4/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0689 - binary_accuracy: 0.9806 - auc: 0.8900
# Epoch 4: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 412ms/step - loss: 0.0689 - binary_accuracy: 0.9806 - auc: 0.8900
# Epoch 5/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0658 - binary_accuracy: 0.9808 - auc: 0.9065
# Epoch 5: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 408ms/step - loss: 0.0658 - binary_accuracy: 0.9808 - auc: 0.9065
# Epoch 6/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0640 - binary_accuracy: 0.9810 - auc: 0.9144
# Epoch 6: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 408ms/step - loss: 0.0640 - binary_accuracy: 0.9810 - auc: 0.9144
# Epoch 7/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0624 - binary_accuracy: 0.9811 - auc: 0.9212
# Epoch 7: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 415ms/step - loss: 0.0624 - binary_accuracy: 0.9811 - auc: 0.9212
# Epoch 8/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0612 - binary_accuracy: 0.9813 - auc: 0.9257
# Epoch 8: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 406ms/step - loss: 0.0612 - binary_accuracy: 0.9813 - auc: 0.9257
# Epoch 9/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0607 - binary_accuracy: 0.9813 - auc: 0.9270
# Epoch 9: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 411ms/step - loss: 0.0607 - binary_accuracy: 0.9813 - auc: 0.9270
# Epoch 10/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0598 - binary_accuracy: 0.9814 - auc: 0.9307
# Epoch 10: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 409ms/step - loss: 0.0598 - binary_accuracy: 0.9814 - auc: 0.9307
# Epoch 11/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0586 - binary_accuracy: 0.9816 - auc: 0.9343
# Epoch 11: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 414ms/step - loss: 0.0586 - binary_accuracy: 0.9816 - auc: 0.9343
# Epoch 12/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0579 - binary_accuracy: 0.9817 - auc: 0.9364
# Epoch 12: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0579 - binary_accuracy: 0.9817 - auc: 0.9364
# Epoch 13/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0573 - binary_accuracy: 0.9818 - auc: 0.9382
# Epoch 13: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 402ms/step - loss: 0.0573 - binary_accuracy: 0.9818 - auc: 0.9382
# Epoch 14/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0570 - binary_accuracy: 0.9818 - auc: 0.9389
# Epoch 14: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 412ms/step - loss: 0.0570 - binary_accuracy: 0.9818 - auc: 0.9389
# Epoch 15/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0561 - binary_accuracy: 0.9820 - auc: 0.9417
# Epoch 15: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0561 - binary_accuracy: 0.9820 - auc: 0.9417
# Epoch 16/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0554 - binary_accuracy: 0.9821 - auc: 0.9434
# Epoch 16: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 401ms/step - loss: 0.0554 - binary_accuracy: 0.9821 - auc: 0.9434
# Epoch 17/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0544 - binary_accuracy: 0.9823 - auc: 0.9463
# Epoch 17: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 402ms/step - loss: 0.0544 - binary_accuracy: 0.9823 - auc: 0.9463
# Epoch 18/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0537 - binary_accuracy: 0.9825 - auc: 0.9478
# Epoch 18: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0537 - binary_accuracy: 0.9825 - auc: 0.9478
# Epoch 19/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0540 - binary_accuracy: 0.9824 - auc: 0.9471
# Epoch 19: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0540 - binary_accuracy: 0.9824 - auc: 0.9471
# Epoch 20/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0524 - binary_accuracy: 0.9827 - auc: 0.9510
# Epoch 20: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 406ms/step - loss: 0.0524 - binary_accuracy: 0.9827 - auc: 0.9510
# Epoch 21/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0521 - binary_accuracy: 0.9828 - auc: 0.9515
# Epoch 21: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 409ms/step - loss: 0.0521 - binary_accuracy: 0.9828 - auc: 0.9515
# Epoch 22/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0511 - binary_accuracy: 0.9830 - auc: 0.9536
# Epoch 22: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0511 - binary_accuracy: 0.9830 - auc: 0.9536
# Epoch 23/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0501 - binary_accuracy: 0.9832 - auc: 0.9566
# Epoch 23: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 410ms/step - loss: 0.0501 - binary_accuracy: 0.9832 - auc: 0.9566
# Epoch 24/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0493 - binary_accuracy: 0.9834 - auc: 0.9579
# Epoch 24: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 419ms/step - loss: 0.0493 - binary_accuracy: 0.9834 - auc: 0.9579
# Epoch 25/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0485 - binary_accuracy: 0.9836 - auc: 0.9595
# Epoch 25: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 409ms/step - loss: 0.0485 - binary_accuracy: 0.9836 - auc: 0.9595
# Epoch 26/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0482 - binary_accuracy: 0.9837 - auc: 0.9600
# Epoch 26: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0482 - binary_accuracy: 0.9837 - auc: 0.9600
# Epoch 27/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0468 - binary_accuracy: 0.9840 - auc: 0.9629
# Epoch 27: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 408ms/step - loss: 0.0468 - binary_accuracy: 0.9840 - auc: 0.9629
# Epoch 28/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0456 - binary_accuracy: 0.9843 - auc: 0.9649
# Epoch 28: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 409ms/step - loss: 0.0456 - binary_accuracy: 0.9843 - auc: 0.9649
# Epoch 29/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0455 - binary_accuracy: 0.9843 - auc: 0.9650
# Epoch 29: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0455 - binary_accuracy: 0.9843 - auc: 0.9650
# Epoch 30/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0446 - binary_accuracy: 0.9846 - auc: 0.9670
# Epoch 30: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 404ms/step - loss: 0.0446 - binary_accuracy: 0.9846 - auc: 0.9670
# Epoch 31/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0438 - binary_accuracy: 0.9848 - auc: 0.9685
# Epoch 31: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 408ms/step - loss: 0.0438 - binary_accuracy: 0.9848 - auc: 0.9685
# Epoch 32/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0422 - binary_accuracy: 0.9852 - auc: 0.9710
# Epoch 32: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 412ms/step - loss: 0.0422 - binary_accuracy: 0.9852 - auc: 0.9710
# Epoch 33/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0426 - binary_accuracy: 0.9851 - auc: 0.9703
# Epoch 33: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 410ms/step - loss: 0.0426 - binary_accuracy: 0.9851 - auc: 0.9703
# Epoch 34/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0403 - binary_accuracy: 0.9858 - auc: 0.9738
# Epoch 34: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 416ms/step - loss: 0.0403 - binary_accuracy: 0.9858 - auc: 0.9738
# Epoch 35/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0395 - binary_accuracy: 0.9859 - auc: 0.9748
# Epoch 35: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 417ms/step - loss: 0.0395 - binary_accuracy: 0.9859 - auc: 0.9748
# Epoch 36/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0387 - binary_accuracy: 0.9862 - auc: 0.9761
# Epoch 36: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 406ms/step - loss: 0.0387 - binary_accuracy: 0.9862 - auc: 0.9761
# Epoch 37/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0374 - binary_accuracy: 0.9866 - auc: 0.9777
# Epoch 37: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 407ms/step - loss: 0.0374 - binary_accuracy: 0.9866 - auc: 0.9777
# Epoch 38/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0376 - binary_accuracy: 0.9865 - auc: 0.9778
# Epoch 38: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 405ms/step - loss: 0.0376 - binary_accuracy: 0.9865 - auc: 0.9778
# Epoch 39/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0362 - binary_accuracy: 0.9869 - auc: 0.9795
# Epoch 39: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 407ms/step - loss: 0.0362 - binary_accuracy: 0.9869 - auc: 0.9795
# Epoch 40/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0354 - binary_accuracy: 0.9872 - auc: 0.9804
# Epoch 40: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 407ms/step - loss: 0.0354 - binary_accuracy: 0.9872 - auc: 0.9804
# Epoch 41/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0346 - binary_accuracy: 0.9874 - auc: 0.9815
# Epoch 41: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 429ms/step - loss: 0.0346 - binary_accuracy: 0.9874 - auc: 0.9815
# Epoch 42/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0344 - binary_accuracy: 0.9874 - auc: 0.9821
# Epoch 42: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 407ms/step - loss: 0.0344 - binary_accuracy: 0.9874 - auc: 0.9821
# Epoch 43/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0321 - binary_accuracy: 0.9883 - auc: 0.9842
# Epoch 43: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 406ms/step - loss: 0.0321 - binary_accuracy: 0.9883 - auc: 0.9842
# Epoch 44/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0318 - binary_accuracy: 0.9883 - auc: 0.9847
# Epoch 44: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 405ms/step - loss: 0.0318 - binary_accuracy: 0.9883 - auc: 0.9847
# Epoch 45/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0315 - binary_accuracy: 0.9883 - auc: 0.9850
# Epoch 45: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 415ms/step - loss: 0.0315 - binary_accuracy: 0.9883 - auc: 0.9850
# Epoch 46/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0308 - binary_accuracy: 0.9886 - auc: 0.9861
# Epoch 46: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 409ms/step - loss: 0.0308 - binary_accuracy: 0.9886 - auc: 0.9861
# Epoch 47/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0294 - binary_accuracy: 0.9890 - auc: 0.9870
# Epoch 47: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 411ms/step - loss: 0.0294 - binary_accuracy: 0.9890 - auc: 0.9870
# Epoch 48/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0287 - binary_accuracy: 0.9893 - auc: 0.9877
# Epoch 48: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 413ms/step - loss: 0.0287 - binary_accuracy: 0.9893 - auc: 0.9877
# Epoch 49/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0278 - binary_accuracy: 0.9896 - auc: 0.9886
# Epoch 49: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 416ms/step - loss: 0.0278 - binary_accuracy: 0.9896 - auc: 0.9886
# Epoch 50/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0272 - binary_accuracy: 0.9898 - auc: 0.9893
# Epoch 50: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 411ms/step - loss: 0.0272 - binary_accuracy: 0.9898 - auc: 0.9893
# Epoch 51/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0275 - binary_accuracy: 0.9896 - auc: 0.9890
# Epoch 51: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 410ms/step - loss: 0.0275 - binary_accuracy: 0.9896 - auc: 0.9890
# Epoch 52/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0269 - binary_accuracy: 0.9898 - auc: 0.9897
# Epoch 52: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 408ms/step - loss: 0.0269 - binary_accuracy: 0.9898 - auc: 0.9897
# Epoch 53/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0257 - binary_accuracy: 0.9903 - auc: 0.9905
# Epoch 53: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 410ms/step - loss: 0.0257 - binary_accuracy: 0.9903 - auc: 0.9905
# Epoch 54/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0245 - binary_accuracy: 0.9907 - auc: 0.9914
# Epoch 54: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 411ms/step - loss: 0.0245 - binary_accuracy: 0.9907 - auc: 0.9914
# Epoch 55/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0235 - binary_accuracy: 0.9911 - auc: 0.9920
# Epoch 55: saving model to training/cp.ckpt
# 23/23 [==============================] - 10s 415ms/step - loss: 0.0235 - binary_accuracy: 0.9911 - auc: 0.9920
# Epoch 56/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0232 - binary_accuracy: 0.9912 - auc: 0.9923
# Epoch 56: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 409ms/step - loss: 0.0232 - binary_accuracy: 0.9912 - auc: 0.9923
# Epoch 57/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0227 - binary_accuracy: 0.9913 - auc: 0.9928
# Epoch 57: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 408ms/step - loss: 0.0227 - binary_accuracy: 0.9913 - auc: 0.9928
# Epoch 58/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0232 - binary_accuracy: 0.9911 - auc: 0.9925
# Epoch 58: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 413ms/step - loss: 0.0232 - binary_accuracy: 0.9911 - auc: 0.9925
# Epoch 59/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0217 - binary_accuracy: 0.9917 - auc: 0.9935
# Epoch 59: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 410ms/step - loss: 0.0217 - binary_accuracy: 0.9917 - auc: 0.9935
# Epoch 60/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0212 - binary_accuracy: 0.9918 - auc: 0.9938
# Epoch 60: saving model to training/cp.ckpt
# 23/23 [==============================] - 9s 413ms/step - loss: 0.0212 - binary_accuracy: 0.9918 - auc: 0.9938
# Epoch 61/100

# %% [markdown]
# ### Calculating Hamming loss and F1 Score on Valid dataset

# %%
# Define the threshold
threshold = 0.5
# model.fit(X_trn,y_trn)
predictions = model.predict(X_tst)
val_preds = np.where(predictions > threshold, 1, 0)
val_labels = y_tst
tp = np.sum((val_preds == 1) & (val_labels == 1))
fp = np.sum((val_preds == 1) & (val_labels == 0))
fn = np.sum((val_preds == 0) & (val_labels == 1))

precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1_score = 2 * (precision * recall) / (precision + recall)
hamming_loss = np.mean(val_preds != val_labels)

print("Hamming loss:", hamming_loss)
print("F-max score:", f1_score)
# Out:
# 890/890 [==============================] - 3s 3ms/step
# Hamming loss: 0.020409529024035943
# F-max score: 0.37890877538001333

# %% [markdown]
# ### If using pre-trained weights

# %%
# Testing
INPUT_SHAPE = (1024, 1) 
BATCH_SIZE = 5120

model = tf.keras.Sequential([
    tf.keras.layers.Reshape(INPUT_SHAPE, input_shape=(1024,)),
    tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu'),
    tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Flatten(),   
    tf.keras.layers.Dense(units=712, activation='leaky_relu'),
    tf.keras.layers.Dense(units=1012, activation='leaky_relu'),
    tf.keras.layers.Dense(units=1499,activation='sigmoid')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['binary_accuracy', tf.keras.metrics.AUC()]
)

# %%
latest = tf.train.latest_checkpoint("/kaggle/input/checkpt")
latest
# Out:
# '/kaggle/input/checkpt/cp.ckpt'

# %%
model.load_weights(latest)

# %%
test_embeddings = np.load('/kaggle/input/protbert-embeddings-for-cafa5/test_embeddings.npy')

column_num = test_embeddings.shape[1]
test_df = pd.DataFrame(test_embeddings, columns = ["Column_" + str(i) for i in range(1, column_num+1)])
print(test_df.shape)
# Out:
# (141865, 1024)

# %% [markdown]
# ### Getting and Saving Predictions

# %%
predictions = model.predict(test_df)
# Out:
# 4434/4434 [==============================] - 9s 2ms/step

# %%
np.save("pred_0.34.npy", predictions)

# %%
t0 = time.time()
# model.fit(X_trn,y_trn)
Y_pred_test = model.predict(X_tst)
tt = time.time() - t0
print("MLP hehe", tt)
l = []
for i in range(y_trn.shape[1]):
    if len(np.unique(X_tst) ) > 1:
        s = roc_auc_score(y_tst[:,i], Y_pred_test[:,i]);
    else:
        s = 0.5
    l.append(s)        
    if i %10 == 0:
        print(i, s)

# %%
df_models_stat = pd.DataFrame()
df_models_stat.loc["MLP",'RocAuc Mean Test'] = np.mean(l)
df_models_stat.loc["MLP",'Time'] = np.round(tt,1)
df_models_stat.loc["MLP",'Test Size'] = len(X_tst)
df_models_stat

# %%
test_df.head()
